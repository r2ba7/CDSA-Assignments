# %% [markdown]
# # 911
# ### Visualize the 911 dataset using those features twp (the town), Reason, hour, month, day of week, Year

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set(rc={'figure.figsize':[8,8]}, font_scale = 1)

# %%
df1 = pd.read_csv('911.csv')
df1
# Out:
#               lat        lng  \
# 0       40.297876 -75.581294
# 1       40.258061 -75.264680
# 2       40.121182 -75.351975
# 3       40.116153 -75.343513
# 4       40.251492 -75.603350
# ...           ...        ...
# 115206  40.265484 -75.293554
# 115207  40.131681 -75.389806
# 115208  40.186753 -75.143373
# 115209  40.155928 -75.141169
# 115210  40.147850 -75.333684
#
#                                                      desc      zip  \
# 0       REINDEER CT & DEAD END;  NEW HANOVER; Station ...  19525.0
# 1       BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...  19446.0
# 2       HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...  19401.0
# 3       AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...  19401.0
# 4       CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...      NaN
# ...                                                   ...      ...
# 115206  WERNER RD & ORVILLA RD;  HATFIELD TOWNSHIP; St...  19440.0
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115211 entries, 0 to 115210
# Data columns (total 14 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   lat          115211 non-null  float64
#  1   lng          115211 non-null  float64
#  2   desc         115211 non-null  object
#  3   zip          100789 non-null  float64
#  4   title        115211 non-null  object
#  5   timeStamp    115211 non-null  object
#  6   twp          115177 non-null  object
#  7   addr         115211 non-null  object
#  8   e            115211 non-null  int64
#  9   Reason       115211 non-null  object
#  10  hour         115211 non-null  int64
#  11  month        115211 non-null  int64
#  12  day of week  115211 non-null  object
#  13  Year         115211 non-null  int64
# dtypes: float64(3), int64(4), object(7)
# memory usage: 12.3+ MB

# %%
df1.describe()
# Out:
#                  lat            lng            zip         e           hour  \
# count  115211.000000  115211.000000  100789.000000  115211.0  115211.000000
# mean       40.159127     -75.317145   19237.423201       1.0      13.064759
# std         0.093297       0.170770     336.415922       0.0       5.662017
# min        30.333596     -95.595595   17752.000000       1.0       0.000000
# 25%        40.100234     -75.391998   19038.000000       1.0       9.000000
# 50%        40.144526     -75.304780   19401.000000       1.0      13.000000
# 75%        40.229008     -75.211866   19446.000000       1.0      17.000000
# max        41.167156     -74.995041   77316.000000       1.0      23.000000
#
#                month           Year
# count  115211.000000  115211.000000
# mean        5.539714    2015.931291
# std         3.115296       0.252959
# min         1.000000    2015.000000
# 25%         3.000000    2016.000000
# 50%         5.000000    2016.000000
# ...

# %%
df1.head()
# Out:
#          lat        lng                                               desc  \
# 0  40.297876 -75.581294  REINDEER CT & DEAD END;  NEW HANOVER; Station ...
# 1  40.258061 -75.264680  BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...
# 2  40.121182 -75.351975  HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...
# 3  40.116153 -75.343513  AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...
# 4  40.251492 -75.603350  CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...
#
#        zip                    title            timeStamp                twp  \
# 0  19525.0   EMS: BACK PAINS/INJURY  2015-12-10 17:10:52        NEW HANOVER
# 1  19446.0  EMS: DIABETIC EMERGENCY  2015-12-10 17:29:21  HATFIELD TOWNSHIP
# 2  19401.0      Fire: GAS-ODOR/LEAK  2015-12-10 14:39:21         NORRISTOWN
# 3  19401.0   EMS: CARDIAC EMERGENCY  2015-12-10 16:47:36         NORRISTOWN
# 4      NaN           EMS: DIZZINESS  2015-12-10 16:56:52   LOWER POTTSGROVE
#
# ...

# %%
plt.subplot(2,1,1)
sns.countplot(data = df1, x = 'Year', palette = 'twilight')
plt.subplot(2,1,2)
sns.countplot(data = df1, x = 'Reason', palette = 'mako')

# %%
df1['twp'].unique()
# Out:
# array(['NEW HANOVER', 'HATFIELD TOWNSHIP', 'NORRISTOWN',
#        'LOWER POTTSGROVE', 'LANSDALE', 'HORSHAM', 'SKIPPACK',
#        'LOWER SALFORD', 'PLYMOUTH', 'MONTGOMERY', 'UPPER MORELAND',
#        'CHELTENHAM', 'UPPER MERION', 'WHITEMARSH', 'UPPER GWYNEDD',
#        'LOWER PROVIDENCE', 'UPPER DUBLIN', 'WHITPAIN', 'DELAWARE COUNTY',
#        'FRANCONIA', 'WEST CONSHOHOCKEN', 'LOWER MERION', 'LIMERICK',
#        'TOWAMENCIN', 'DOUGLASS', 'POTTSTOWN', 'BRIDGEPORT', 'AMBLER',
#        'CHESTER COUNTY', 'UPPER HANOVER', 'SPRINGFIELD', 'ROCKLEDGE',
#        'ABINGTON', 'WEST NORRITON', 'ROYERSFORD', 'UPPER SALFORD',
#        'LOWER MORELAND', 'CONSHOHOCKEN', 'PENNSBURG', 'TELFORD',
#        'EAST NORRITON', 'UPPER FREDERICK', 'UPPER PROVIDENCE', 'SALFORD',
#        'HATFIELD BORO', 'LEHIGH COUNTY', 'LOWER GWYNEDD', 'MARLBOROUGH',
#        'BRYN ATHYN', 'HATBORO', 'WORCESTER', 'COLLEGEVILLE',
#        'SCHWENKSVILLE', 'PERKIOMEN', 'SOUDERTON', 'UPPER POTTSGROVE',
# ...

# %%
plt.subplot(2,1,1)
sns.countplot(data = df1, x = df1['twp'], order = df1['twp'].value_counts().index[0:5], palette = 'mako')
plt.subplot(2,1,2)
sns.countplot(data = df1, x = df1['twp'], order = df1['twp'].value_counts().index[0:5], hue = 'Reason', palette = 'plasma')

# %%
plt.subplot(2,1,1)
sns.countplot(data = df1, x = df1['hour'])
plt.subplot(2,1,2)
sns.countplot(data = df1, x = df1['hour'], hue = 'Reason')

# %%
plt.subplot(2,1,1)
sns.countplot(data = df1, x = df1['month'])
plt.subplot(2,1,2)
sns.countplot(data = df1, x = df1['month'], hue = 'Reason')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115211 entries, 0 to 115210
# Data columns (total 15 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   lat          115211 non-null  float64
#  1   lng          115211 non-null  float64
#  2   desc         115211 non-null  object
#  3   zip          100789 non-null  float64
#  4   title        115211 non-null  object
#  5   timeStamp    115211 non-null  object
#  6   twp          115177 non-null  object
#  7   addr         115211 non-null  object
#  8   e            115211 non-null  int64
#  9   Reason       115211 non-null  object
#  10  hour         115211 non-null  int64
#  11  month        115211 non-null  int64
#  12  day of week  115211 non-null  object
#  13  Year         115211 non-null  int64
#  14  twp_cat      115177 non-null  category
# dtypes: category(1), float64(3), int64(4), object(7)
# memory usage: 12.4+ MB

# %%
sns.catplot(x="Reason", kind="count", palette="ch:.25", data=df1, hue = 'month')

# %%
sns.catplot(x="day of week", kind="count", palette="ch:.25", data=df1, hue = 'Year')

# %%
sns.catplot(x="month", kind="count", palette="mako", data=df1, hue = 'Year')

# %%
df1_table = pd.pivot_table(data = df1, values = 'hour', index = df1['twp'], columns ='Reason', aggfunc= np.sum)
df1_table
# Out:
# Reason             EMS   Fire  Traffic
# twp
# ABINGTON         45209  14628    30784
# AMBLER            4919   2119     2063
# BERKS COUNTY      4267      7      164
# BRIDGEPORT        3902   1490     2956
# BRYN ATHYN         995    662      958
# ...                ...    ...      ...
# WEST NORRITON    13125   3734     7279
# WEST POTTSGROVE   3612   2109     2515
# WHITEMARSH       16008   6960    15867
# WHITPAIN         15399   4862    11488
# WORCESTER         5274   2186     4450
#
# [68 rows x 3 columns]

# %%
#The heat map doesn't make sense I know, I was only trying
sns.heatmap(df1_table, cmap= 'YlOrBr', linewidths = 1)

# %% [markdown]
# ### I tried another plots but the data is so limited

# %% [markdown]
# # Titanic

# %% [markdown]
# ### Visualize the titanic dataset using those features survived, sex, age, fare, class, who, embark_town, alive, alone

# %%
df2 = pd.read_csv('titanic.csv')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    object
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    object
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), float64(2), int64(4), object(7)
# memory usage: 92.4+ KB

# %%
df2.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df2.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
fig, axes = plt.subplots(3, figsize = (10,10))
fig.suptitle('Plots')
sns.countplot( data = df2, x = 'survived', hue = 'sex', ax = axes[0])
sns.countplot( data = df2, x = 'survived', hue = 'who', palette = 'Blues_r', ax = axes[1])
sns.countplot( data = df2, x = 'survived', hue = 'alone', palette = 'ocean', ax = axes[2])

# %%
sns.histplot(data = df2, x = 'fare', bins = 15, color = 'k')

# %%
sns.boxplot(x='who', y ='fare', data= df2 , hue= 'survived')

# %%
sns.boxplot(x='sex', y ='age', data= df2 , hue= 'survived', palette = 'gray')

# %%
sns.stripplot(x='sex', y ='age', data= df2 , hue= 'survived', palette = 'mako')

# %%
sns.stripplot(x='who', y ='age', data= df2 , hue= 'survived', palette = 'mako')

# %%
sns.boxplot(x='survived', y ='age', data= df2 , hue= 'who', palette = 'mako')

# %%
sns.violinplot(x= 'class', y='age' , data=df2, hue= 'sex', split= True )

# %%
fig, axes = plt.subplots(2,2 , figsize= (20, 10)) 
fig.suptitle ('Plots')
sns.boxplot(ax=axes [0][0], x = 'embark_town', y ='age' , data= df2 , hue= 'alive', palette = 'twilight', dodge = True)
sns.boxplot(ax=axes [0] [1], x = 'alive', y='age', data=df2, hue= 'alone', palette = 'gist_stern')
sns.stripplot (ax = axes [1][0], x = 'class', y ='age', data= df2, hue = 'sex')
sns.violinplot(ax = axes [1][1], x = 'survived', y='age', data=df2, hue= 'alone' , palette='mako')

# %%
sns.barplot(x='who', y ='age', data = df2, estimator=np.sum, hue='survived' , palette='mako')

# %%
sns.jointplot(x = 'age' , y ='fare' , data= df2)

# %%
sns.pairplot(df2)
# Out:
# <string>:6: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <string>:6: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <string>:6: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <string>:6: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.

# %%
sns.barplot(x='who' , y ='age' , data=df2 , palette='Accent', hue='embark_town')

# %%
df2.corr()
# Out:
#             survived    pclass       age     sibsp     parch      fare  \
# survived    1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# pclass     -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# age        -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# sibsp      -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# parch       0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# fare        0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000
# adult_male -0.557080  0.094035  0.280328 -0.253586 -0.349943 -0.182024
# alone      -0.203367  0.135207  0.198270 -0.584471 -0.583398 -0.271832
#
#             adult_male     alone
# survived     -0.557080 -0.203367
# pclass        0.094035  0.135207
# age           0.280328  0.198270
# sibsp        -0.253586 -0.584471
# parch        -0.349943 -0.583398
# fare         -0.182024 -0.271832
# adult_male    1.000000  0.404744
# alone         0.404744  1.000000

# %%
sns.heatmap(df2.corr(), cmap= 'cividis', annot = True)
