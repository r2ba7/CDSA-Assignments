# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
sns.set(rc={'figure.figsize':(20,25)})
#a4_dims = (11.7, 8.27)
#fig, ax = pyplot.subplots(figsize=a4_dims)

# %%
df = pd.read_csv('country_wise_latest.csv')
df
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country/Region          187 non-null    object
#  1   Confirmed               187 non-null    int64
#  2   Deaths                  187 non-null    int64
#  3   Recovered               187 non-null    int64
#  4   Active                  187 non-null    int64
#  5   New cases               187 non-null    int64
#  6   New deaths              187 non-null    int64
#  7   New recovered           187 non-null    int64
#  8   Deaths / 100 Cases      187 non-null    float64
#  9   Recovered / 100 Cases   187 non-null    float64
#  10  Deaths / 100 Recovered  187 non-null    float64
#  11  Confirmed last week     187 non-null    int64
#  12  1 week change           187 non-null    int64
#  13  1 week % increase       187 non-null    float64
# ...

# %%
df.describe()
# Out:
#           Confirmed         Deaths     Recovered        Active     New cases  \
# count  1.870000e+02     187.000000  1.870000e+02  1.870000e+02    187.000000
# mean   8.813094e+04    3497.518717  5.063148e+04  3.400194e+04   1222.957219
# std    3.833187e+05   14100.002482  1.901882e+05  2.133262e+05   5710.374790
# min    1.000000e+01       0.000000  0.000000e+00  0.000000e+00      0.000000
# 25%    1.114000e+03      18.500000  6.265000e+02  1.415000e+02      4.000000
# 50%    5.059000e+03     108.000000  2.815000e+03  1.600000e+03     49.000000
# 75%    4.046050e+04     734.000000  2.260600e+04  9.149000e+03    419.500000
# max    4.290259e+06  148011.000000  1.846641e+06  2.816444e+06  56336.000000
#
#         New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# count   187.000000     187.000000          187.000000             187.000000
# mean     28.957219     933.812834            3.019519              64.820535
# ...

# %% [markdown]
# ### Plotting Confirmed/Deaths/Recovered/Active for a sample of 10 nations

# %%
plt.subplot(5,1,1)
sns.countplot(data = df, x = 'WHO Region', palette = 'Blues', order = df['WHO Region'].value_counts().index)
plt.subplot(5,1,2)
sns.barplot(data = df, x = df['Country/Region'].sample(n = 10), y = 'Confirmed', palette = 'mako', hue = 'WHO Region')
plt.subplot(5,1,3)
sns.barplot(data = df, x = df['Country/Region'].sample(n = 10), y = 'Deaths', palette = 'mako', hue = 'WHO Region')
plt.subplot(5,1,4)
sns.barplot(data = df, x = df['Country/Region'].sample(n = 10), y = 'Recovered', palette = 'mako', hue = 'WHO Region')
plt.subplot(5,1,5)
sns.barplot(data = df, x = df['Country/Region'].sample(n = 10), y = 'Active', palette = 'mako', hue = 'WHO Region')

# %% [markdown]
# ### Plotting New cases/New deaths/New recovered for a sample of 10 nations

# %%
plt.subplot(3,1,1)
sns.barplot(data = df, x = df['Country/Region'].sample(n = 10), y = 'New cases', palette = 'mako', hue = 'WHO Region')
plt.subplot(3,1,2)
sns.barplot(data = df, x = df['Country/Region'].sample(n = 10), y = 'New deaths', palette = 'mako', hue = 'WHO Region')
plt.subplot(3,1,3)
sns.barplot(data = df, x = df['Country/Region'].sample(n = 10), y = 'New recovered', palette = 'mako', hue = 'WHO Region')

# %%
sum(df[df['WHO Region'] == 'Europe']['Confirmed'])
# Out:
# 3299523

# %% [markdown]
# # The below plots are more statistical than informative
# ### We can neglect the 3 graphs below

# %%
#From the above cell, we can get the total Confirmed in each continent, but how can we visualize it ?
#Solution is below after alot of searching. :)
plt.subplot(311)
sns.boxplot(data = df, x = df['WHO Region'], y = 'Confirmed', palette = 'mako')
plt.subplot(312)
sns.violinplot(data = df, x = df['WHO Region'], y = 'Deaths', palette = 'mako')
plt.subplot(313)
sns.stripplot(data = df, x = df['WHO Region'], y = 'Recovered', palette = 'mako')

# %% [markdown]
# ### Plotting Confirmed/Recovered/Deaths with hue as continent to know which continents were vulnerable

# %%
plt.subplot(311)
sns.histplot(data = df, x = 'Confirmed', bins = 50, hue = 'WHO Region')
plt.subplot(312)
sns.histplot(data = df, x = 'Recovered', bins = 50, color = 'cy', hue = 'WHO Region')
plt.subplot(313)
sns.histplot(data = df, x = 'Deaths', bins = 50, color = 'k', hue = 'WHO Region')

# %% [markdown]
# ### Relations between Confirmed/Deaths and Confirmed/Recovered

# %%
sns.jointplot(data = df, x = 'Confirmed', y = 'Deaths', hue = 'WHO Region', palette = 'Blues')

# %%
sns.jointplot(data = df, x = 'Confirmed', y = 'Recovered', hue = 'WHO Region', palette = 'Blues')

# %% [markdown]
# ### Correlation and Heatmap after dropping some unnecessarily columns

# %%
df['WHO_cat'] = df['WHO Region'].astype("category").cat.codes
df2 = df.drop(columns = ['Deaths / 100 Cases', 'Recovered / 100 Cases', 'Deaths / 100 Recovered', '1 week % increase'])
#df.corr()
df2.corr()
# Out:
#                      Confirmed    Deaths  Recovered    Active  New cases  \
# Confirmed             1.000000  0.934698   0.906377  0.927018   0.909720
# Deaths                0.934698  1.000000   0.832098  0.871586   0.806975
# Recovered             0.906377  0.832098   1.000000  0.682103   0.818942
# Active                0.927018  0.871586   0.682103  1.000000   0.851190
# New cases             0.909720  0.806975   0.818942  0.851190   1.000000
# New deaths            0.871683  0.814161   0.820338  0.781123   0.935947
# New recovered         0.859252  0.765114   0.919203  0.673887   0.914765
# Confirmed last week   0.999127  0.939082   0.899312  0.931459   0.896084
# 1 week change         0.954710  0.855330   0.910013  0.847642   0.959993
# WHO_cat              -0.016127 -0.005803  -0.001206 -0.027519  -0.009019
#
#                      New deaths  New recovered  Confirmed last week  \
# Confirmed              0.871683       0.859252             0.999127
# ...

# %%
#sns.heatmap(df.corr(), cmap = 'Blues', linewidths = 2)
a4_dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize=a4_dims)
sns.heatmap(df2.corr(), cmap = 'Blues', linewidths = 2, annot = True)

# %% [markdown]
# ### Every Continent information for the 2 Data Frames

# %%
df.groupby('WHO Region').sum().sort_values(by='Confirmed', ascending=False)
# Out:
#                        Confirmed  Deaths  Recovered   Active  New cases  \
# WHO Region
# Americas                 8839286  342732    4468616  4027938     129531
# Europe                   3299523  211144    1993723  1094656      22294
# South-East Asia          1835297   41349    1156933   637015      48993
# Eastern Mediterranean    1490744   38339    1201400   251005      12410
# Africa                    723207   12223     440645   270339      12176
# Western Pacific           292428    8249     206770    77409       3289
#
#                        New deaths  New recovered  Deaths / 100 Cases  \
# WHO Region
# Americas                     3555          94776              106.84
# Europe                        304          11732              235.11
# South-East Asia               734          37582               12.96
# Eastern Mediterranean         445          14843               78.39
# Africa                        353          14563              110.71
# ...

# %%
fig, ax = plt.subplots(figsize=(13,8))
df.groupby('WHO Region').sum().sort_values(by='Confirmed', ascending=False).plot(ax=ax, kind='bar', lw = 1.5)

# %%
df2.drop(columns = 'WHO_cat', inplace = True)
df2.groupby('WHO Region').sum().sort_values(by='Confirmed', ascending=False)
# Out:
#                        Confirmed  Deaths  Recovered   Active  New cases  \
# WHO Region
# Americas                 8839286  342732    4468616  4027938     129531
# Europe                   3299523  211144    1993723  1094656      22294
# South-East Asia          1835297   41349    1156933   637015      48993
# Eastern Mediterranean    1490744   38339    1201400   251005      12410
# Africa                    723207   12223     440645   270339      12176
# Western Pacific           292428    8249     206770    77409       3289
#
#                        New deaths  New recovered  Confirmed last week  \
# WHO Region
# Americas                     3555          94776              7815198
# Europe                        304          11732              3146816
# South-East Asia               734          37582              1478283
# Eastern Mediterranean         445          14843              1398847
# Africa                        353          14563               608120
# ...

# %%
fig, ax = plt.subplots(figsize=(13,8))
df2.groupby('WHO Region').sum().sort_values(by='Confirmed', ascending=False).plot(ax=ax, kind='bar', lw = 1.5)

# %% [markdown]
# ### Focusing on the Confirmed column

# %%
labels = 'Americas', 'Europe', 'South-East Asia', 'Eastern Mediterranean', 'Africa', 'Western Pacific'
sizes = [8839286, 3299523, 1835297, 1490744, 723207, 292428]
explode = (0.01, 0, 0, 0, 0, 0)
fig1, ax1 = plt.subplots(figsize=(10,10))
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%', startangle=90)
ax1.axis('equal')
plt.show()

# %%
df
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
df.groupby('WHO Region').sum().sort_values(by='Confirmed', ascending=False)['Confirmed']
# Out:
# WHO Region
# Americas                 8839286
# Europe                   3299523
# South-East Asia          1835297
# Eastern Mediterranean    1490744
# Africa                    723207
# Western Pacific           292428
# Name: Confirmed, dtype: int64

# %% [markdown]
# # Some insights about the data

# %%
df
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
print('The most affected country is:', df[df['Confirmed'] == df['Confirmed'].max()]['Country/Region'].to_string(index=False))
print('With total cases of :', df[df['Confirmed'] == df['Confirmed'].max()]['Confirmed'].to_string(index=False), 'Case')
# Out:
# The most affected country is:  US
# With total cases of :  4290259 Case

# %% [markdown]
# ### From the Dataframe below we notice that Brazil has the highest Recovered, but what about Brazil cases ?

# %%
df[['Country/Region', 'Recovered', 'WHO Region']].sort_values(by='Recovered', ascending=False).head()
# Out:
#     Country/Region  Recovered       WHO Region
# 23          Brazil    1846641         Americas
# 173             US    1325804         Americas
# 79           India     951166  South-East Asia
# 138         Russia     602249           Europe
# 35           Chile     319954         Americas

# %%
print('Brazil Confirmed Cases are: ',df[df['Country/Region'] == 'Brazil']['Confirmed'].to_string(index=False), 'Cases')
print("The ratio between Recovered and Confirmed is : ", int(df[df['Country/Region'] == 'Brazil']['Recovered'].to_string(index=False))/int(df[df['Country/Region'] == 'Brazil']['Confirmed'].to_string(index=False)))
# Out:
# Brazil Confirmed Cases are:   2442375 Cases
# The ratio between Recovered and Confirmed is :  0.7560841394134807

# %%
df[['Country/Region','1 week % increase', 'WHO Region']].sort_values(by='1 week % increase', ascending=False).head()
# Out:
#        Country/Region  1 week % increase             WHO Region
# 130  Papua New Guinea             226.32        Western Pacific
# 63             Gambia             191.07                 Africa
# 11            Bahamas             119.54               Americas
# 186          Zimbabwe              57.85                 Africa
# 99              Libya              42.78  Eastern Mediterranean

# %% [markdown]
# ### From the above table, we will study Papua New Guinea since it has the highest %increase

# %%
df[df['Country/Region'] == 'Papua New Guinea'][['Confirmed', 'Confirmed last week', '1 week change']]
# Out:
#      Confirmed  Confirmed last week  1 week change
# 130         62                   19             43

# %%
print('Papua New Guinea Confirmed:', df[df['Country/Region'] == 'Papua New Guinea']['Confirmed'].to_string(index=False))
print('Last week was:', df[df['Country/Region'] == 'Papua New Guinea']['Confirmed last week'].to_string(index=False))
print('Deaths:', df[df['Country/Region'] == 'Papua New Guinea']['Deaths'].to_string(index=False))
# Out:
# Papua New Guinea Confirmed:  62
# Last week was:  19
# Deaths:  0

# %% [markdown]
# ### After some searching, Papua New Guinea is an island, with total population approximatly = 9 mil.

# %% [markdown]
# ### What about some other Island Nations ?

# %%
df[df['Country/Region'] == 'Cuba']
# Out:
#    Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 44           Cuba       2532      87       2351      94         37
#
#     New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 44           0              2                3.44                  92.85
#
#     Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 44                     3.7                 2446             86
#
#     1 week % increase WHO Region  WHO_cat
# 44               3.52   Americas        1

# %%
df[(df['Country/Region'] == 'Haiti') | (df['Country/Region'] == 'Cuba') | (df['Country/Region'] == 'Madagascar') | (df['Country/Region'] == 'Philippines') | (df['Country/Region'] == 'Japan') | (df['Country/Region'] == 'United Kingdom') | (df['Country/Region'] == 'Fiji')][['Country/Region','Confirmed','1 week % increase', 'WHO Region']]
# Out:
#      Country/Region  Confirmed  1 week % increase       WHO Region
# 44             Cuba       2532               3.52         Americas
# 59             Fiji         27               0.00  Western Pacific
# 74            Haiti       7340               4.07         Americas
# 87            Japan      31142              21.15  Western Pacific
# 103      Madagascar       9690              35.47           Africa
# 133     Philippines      82040              19.07  Western Pacific
# 177  United Kingdom     301708               1.60           Europe

# %% [markdown]
# ### We can deduce from above that, some island country may have high population like japan 126mil and still have high confirmed cases due to different nationalities, working opportuinites and various travelling methods, others like Fiji low population and low Confirmed due to it's being relatively Isolated due to others

# %% [markdown]
# # The countries in which has the highest chance of survival

# %% [markdown]
# ### Some countries due to it's low population, others due to their advanced medical systems.

# %%
df[(df['Recovered / 100 Cases'] > 64.82053475935835) &(df['Deaths / 100 Cases'] > 3.0195187165775392)][['Country/Region', 'Confirmed','Recovered / 100 Cases', 'Deaths / 100 Cases']].sort_values(by='Recovered / 100 Cases',ascending=False).head(10)
# Out:
#     Country/Region  Confirmed  Recovered / 100 Cases  Deaths / 100 Cases
# 56         Estonia       2034                  94.54                3.39
# 143     San Marino        699                  93.99                6.01
# 60         Finland       7398                  93.54                4.45
# 44            Cuba       2532                  92.85                3.44
# 65         Germany     207112                  91.89                4.41
# 47         Denmark      13761                  91.60                4.45
# 36           China      86783                  90.88                5.37
# 123          Niger       1132                  90.72                6.10
# 83         Ireland      25892                  90.24                6.81
# 113         Monaco        116                  89.66                3.45

# %% [markdown]
# # Summary

# %% [markdown]
# ### For different ratioes of recovery and deaths, it depends on the geography and population of the nation itself, eg: San Marino, it's a mountainous microstate surrounded by north-central Italy, with 33k population.
# ### Others like Germany, Denmark, Finland despite being one of the first-world countries, but have a high chance or recovery due to the advanced medical system etc..
